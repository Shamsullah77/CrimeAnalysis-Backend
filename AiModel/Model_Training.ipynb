# %% [markdown]
# My First Notebook

# %%
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import pandas as pd
import joblib
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform
from scipy.stats import randint
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, StackingRegressor
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.decomposition import TruncatedSVD
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from scipy.sparse import hstack
from scipy import sparse
import pandas as pd
import numpy as np
import seaborn as sns

from copy import deepcopy

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
traindf = pd.read_csv('data.csv')
traindf.head(10)
# Out:
#                             date  economic_index  education_index  \
# 0  2023-01-22 00:00:00.000000000       55.853835        97.134486
# 1  2022-05-06 00:00:00.000000000       92.457588        32.527072
# 2  2021-09-28 00:00:00.000000000       65.258455        45.246258
# 3  2023-06-01 00:00:00.000000000       89.312750         7.412211
# 4  2023-04-19 00:00:00.000000000       80.819762        93.827057
# 5  2020-07-10 00:00:00.000000000        4.478798        95.212256
# 6  2021-10-27 00:00:00.000000000       37.259142        31.823105
# 7  2020-07-29 00:00:00.000000000       89.028157        90.968228
# 8  2023-08-29 00:00:00.000000000       66.062181        92.230629
# 9  2022-08-04 00:00:00.000000000       66.614210        81.947911
#
#    hour_of_day  perpetrator_age  temperature  victim_age       location  \
# 0            5              100    33.924282          79          Daman
# 1           17               69    26.132295          51         Center
# ...

# %%
traindf.describe()
# Out:
#        economic_index  education_index  hour_of_day  perpetrator_age  \
# count     3020.000000      3020.000000  3020.000000      3020.000000
# mean        49.471546        49.891478    12.452318        54.734106
# std         29.070547        28.502110     6.928111        26.114213
# min          0.017304         0.001588     1.000000        10.000000
# 25%         23.947430        24.735247     6.000000        33.000000
# 50%         49.464030        50.063283    12.000000        55.000000
# 75%         74.871268        74.203062    19.000000        77.000000
# max         99.989857        99.925654    24.000000       100.000000
#
#        temperature   victim_age
# count  3020.000000  3020.000000
# mean     15.055112    50.399338
# std      14.370210    28.849051
# min      -9.992881     1.000000
# 25%       2.692672    26.000000
# 50%      14.983609    50.000000
# 75%      27.570965    75.000000
# max      39.999018   100.000000

# %% [markdown]
# this is the jupter

# %%
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import pandas as pd
import joblib
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform
from scipy.stats import randint
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, StackingRegressor
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.decomposition import TruncatedSVD
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from scipy.sparse import hstack
from scipy import sparse
import pandas as pd
import numpy as np
import seaborn as sns

from copy import deepcopy

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
traindf = pd.read_csv('data.csv')
traindf.head(10)
# Out:
#          date  hour_of_day       location victim_gender  victim_age  \
# 0  2023-04-11           23           Reag          Male          49
# 1  2022-09-22           14  Shah Wali Kot        Female          20
# 2  2021-05-31           19           Reag          Male          95
# 3  2021-06-23           11       Panjwayi          Male          63
# 4  2022-09-19           16         Center          Male          11
# 5  2023-12-01           20          Daman          Male          51
# 6  2023-10-22            7          Daman          Male          26
# 7  2021-06-26           13          Maruf        Female          53
# 8  2020-02-09           10          Zhari          Male          31
# 9  2021-05-23            3          Maruf        Female          83
#
#   perpetrator_gender  perpetrator_age weapon  injury weather  ...  crime_type  \
# 0               Male               28    Gun     NaN   Clear  ...       Theft
# ...

# %%
traindf.describe()
# Out:
#        hour_of_day   victim_age  perpetrator_age  temperature  economic_index  \
# count  3000.000000  3000.000000      3000.000000  3000.000000     3000.000000
# mean     12.767333    49.352333        50.871333    15.137253       50.499547
# std       6.901914    28.798275        29.217506    14.397169       29.140483
# min       1.000000     1.000000         1.000000    -9.989043        0.021818
# 25%       7.000000    24.000000        25.000000     2.787845       24.419483
# 50%      13.000000    49.000000        51.000000    15.275729       50.809257
# 75%      19.000000    74.000000        76.000000    27.714624       75.981981
# max      24.000000   100.000000       100.000000    39.922089       99.979372
#
#        education_index
# count      3000.000000
# mean         49.546115
# std          29.014926
# min           0.018741
# 25%          23.868424
# 50%          49.693256
# 75%          74.507013
# max          99.979389

# %%
# Assuming 'traindf' is your dataframe
crime_counts = traindf['crime_type'].value_counts()
location_counts = traindf['location'].value_counts()

print("Crime Type Counts:")
print(crime_counts)

print("\nLocation Counts:")
print(location_counts)
# Out:
# Crime Type Counts:
# crime_type
# Kill     1555
# Theft    1445
# Name: count, dtype: int64
#
# Location Counts:
# location
# Panjwayi         279
# Reag             269
# Maywand          265
# Nesh             255
# Zhari            251
# Daman            248
# Shah Wali Kot    246
# Center           244
# Spin Boldak      241
# Maruf            239
# Arghistan        235
# Kharkrez         228
# Name: count, dtype: int64

# %%
# Count occurrences of each crime type and location
crime_type_counts = traindf['crime_type'].value_counts()
location_counts = traindf['location'].value_counts()

print("Crime Type Counts:")
print(crime_type_counts)

print("\nLocation Counts:")
print(location_counts)
# Out:
# Crime Type Counts:
# crime_type
# Kill     1555
# Theft    1445
# Name: count, dtype: int64
#
# Location Counts:
# location
# Panjwayi         279
# Reag             269
# Maywand          265
# Nesh             255
# Zhari            251
# Daman            248
# Shah Wali Kot    246
# Center           244
# Spin Boldak      241
# Maruf            239
# Arghistan        235
# Kharkrez         228
# Name: count, dtype: int64

# %%
# Replace 'Preferred Career Path' and 'Accommodation Mode' with relevant columns from your dataset
cross_table = pd.crosstab(traindf['crime_type'], traindf['location'])

print("Cross-tabulation of Crime Type and Location:")
print(cross_table)
# Out:
# Cross-tabulation of Crime Type and Location:
# location    Arghistan  Center  Daman  Kharkrez  Maruf  Maywand  Nesh  \
# crime_type
# Kill              118     121    138       105    115      129   132
# Theft             117     123    110       123    124      136   123
#
# location    Panjwayi  Reag  Shah Wali Kot  Spin Boldak  Zhari
# crime_type
# Kill             156   145            138          140    118
# Theft            123   124            108          101    133

# %%
# Example: Crosstab and plot for Crime Type and Location
pd.crosstab(traindf['crime_type'], traindf['location']).plot(kind='bar', figsize=(12, 8))

plt.title("Crime Type Frequency for Different Locations")
plt.xlabel("Crime Type")
plt.ylabel("Frequency")
plt.legend(title='Location', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
# Plot histogram for victim age
plt.figure(figsize=(10, 6))
traindf['victim_age'].plot.hist(bins=20, edgecolor='black')
plt.title('Histogram of Victim Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Plot histogram for a relevant attribute (example: victim_age)
traindf['victim_age'].plot.hist(bins=20, edgecolor='black')
plt.title('Distribution of Victim Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Define the numeric and categorical features based on your dataset
numeric_features = ['victim_age', 'perpetrator_age', 'economic_index', 'education_index']
categorical_features = ['location', 'district', 'victim_gender', 'perpetrator_gender', 'weapon', 'weather_condition']

# Custom Transformer for Data Preprocessing
class DataPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self, numeric_features, categorical_features):
        self.numeric_features = numeric_features
        self.categorical_features = categorical_features
        
        self.numeric_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ])
        
        self.categorical_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ])
        
        self.preprocessor = ColumnTransformer([
            ('numeric', self.numeric_pipeline, self.numeric_features),
            ('categorical', self.categorical_pipeline, self.categorical_features)
        ])
        
    def fit(self, X, y=None):
        self.preprocessor.fit(X)
        return self
    
    def transform(self, X):
        return self.preprocessor.transform(X)

# Example usage:
# Instantiate the DataPreprocessor
data_preprocessor = DataPreprocessor(numeric_features, categorical_features)

# Fit and transform your data
X_processed = data_preprocessor.fit_transform(traindf)

# At this point, X_processed will contain your preprocessed data
# You can proceed to train your predictive model using X_processed and your target variables (crime type and location)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Shamsullah\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'district'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Define your features (X) and target (y)
X = traindf.drop(['crime_type', 'location'], axis=1)  # Adjust columns as per your actual column names
y_crime_type = traindf['crime_type']
y_location = traindf['location']

# Check for any null values in your target variables
print("Null values in Crime Type:")
print(y_crime_type.isnull().any())

print("\nNull values in Location:")
print(y_location.isnull().any())
# Out:
# Null values in Crime Type:
# False
#
# Null values in Location:
# False

# %%
# Define features and target variables
features = traindf[['date', 'hour_of_day', 'location', 'district', 'area_name',
                    'victim_gender', 'victim_age', 'perpetrator_gender', 'perpetrator_age',
                    'weapon', 'longitude', 'time_of_day', 'day_of_week', 'month', 'season',
                    'victim_age_group', 'perpetrator_age_group', 'weather_condition',
                    'economic_index', 'education_index']]

target = traindf[['crime_type', 'location']]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Output the results
print("X_train:")
print(x_train.head())

print("\nX_test:")
print(x_test.head())

print("\nY_train:")
print(y_train.head())

print("\nY_test:")
print(y_test.head())
# Out:
# X_train:
#       date  hour_of_day  location  district  area_name  victim_gender  \
# 642    987    -0.788116       682         2        682              0
# 700    267    -1.659873       209        10        209              1
# 226    948    -1.514580       397         7        397              0
# 1697    12    -0.497531       441        11        441              0
# 1010   266     0.228933       465         0        465              1
#
#       victim_age  perpetrator_gender  perpetrator_age  weapon  longitude  \
# 642    -1.515750                   0         1.120001       1   0.702788
# 700    -0.237773                   1         0.332859       1   0.280260
# 226     0.314866                   0         1.530684       1  -1.384227
# 1697    1.558303                   0        -0.693849       1  -0.569875
# 1010    0.971124                   0         1.701802       0  -0.207479
#
#       time_of_day  day_of_week  month  season  victim_age_group  \
# ...

# %%
# Split the data into features and target variables
X = df.drop(['crime_type', 'location'], axis=1)
y_crime_type = df['crime_type']
y_location = df['location']

# Split into training and test sets
X_train, X_test, y_crime_type_train, y_crime_type_test, y_location_train, y_location_test = train_test_split(
    X, y_crime_type, y_location, test_size=0.2, random_state=42
)

# Identify numerical and categorical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X_train.select_dtypes(include=['category', 'object']).columns

print("The numerical cols:", numerical_cols)
print("The categorical cols:", categorical_cols)

# Create column transformer
col_tsf = make_column_transformer(
    (make_pipeline(SimpleImputer(strategy='median'), StandardScaler()), numerical_cols),
    (make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore')), categorical_cols),
    remainder='passthrough'
)

# Fit and transform the training data
X_preprocessed_train = col_tsf.fit_transform(X_train)
X_preprocessed_test = col_tsf.transform(X_test)

# Save the column transformer
joblib.dump(col_tsf, 'column_transformer.pkl')

print("Preprocessing completed and transformer saved.")
# Out:
# The numerical cols: Index(['hour_of_day', 'victim_age', 'perpetrator_age', 'temperature',
#        'latitude', 'longitude', 'economic_index', 'education_index'],
#       dtype='object')
# The categorical cols: Index(['date', 'district', 'area_name', 'victim_gender', 'perpetrator_gender',
#        'weapon', 'injury', 'weather', 'previous_activity',
#        'economical_situation', 'education_level', 'time_of_day', 'day_of_week',
#        'month', 'season', 'victim_age_group', 'perpetrator_age_group',
#        'weather_condition'],
#       dtype='object')
# Preprocessing completed and transformer saved.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# Specify numerical and categorical columns
numerical_cols = [
    'victim_age', 'perpetrator_age', 'economic_index',
    'education_index', 'latitude', 'longitude'
]
categorical_cols = [
    'location', 'district', 'area_name', 'victim_gender',
    'perpetrator_gender', 'weapon', 'weather_condition', 'crime_type'
]

# Correlation matrix for numerical data
correlation_matrix = df[numerical_cols].corr()
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, linewidths=0.5, fmt=".2f", cmap="YlGnBu", ax=ax)
plt.title("Correlation Matrix - Numerical Data")
plt.show()

# Label encoding for categorical data
label_encoder = LabelEncoder()
encoded_columns = {}

for column in categorical_cols:
    df[column + '_encoded'] = label_encoder.fit_transform(df[column])
    encoded_columns[column + '_encoded'] = df[column + '_encoded']

cat_df = pd.DataFrame(encoded_columns)
cat_corr = cat_df.corr()

fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(cat_corr, annot=True, linewidths=0.5, fmt=".2f", cmap="YlGnBu", ax=ax)
plt.title("Correlation Matrix - Categorical Data")
plt.show()

# Combined data for further analysis
combined_data = pd.concat([df[numerical_cols], cat_df], axis=1)

print("Combined Data:")
print(combined_data.head())
# Out:
# Combined Data:
#    victim_age  perpetrator_age  economic_index  education_index  latitude  \
# 0          43                6       79.058164        30.831159  31.53230
# 1          25               87       29.381859        27.852306  32.18836
# 2          30               67       27.427779        98.695809  31.54848
# 3          90               59       91.489361        40.232219  31.38761
# 4          67               63       70.626686        14.110106  31.69213
#
#    longitude  location_encoded  district_encoded  area_name_encoded  \
# 0   65.35742               206                11                206
# 1   65.56612               395                 5                395
# 2   64.90340               245                 7                245
# 3   66.12366               629                 1                629
# 4   65.66889               717                 0                717
#
#    victim_gender_encoded  perpetrator_gender_encoded  weapon_encoded  \
# ...

# %%
combined_data
# Out:
#       victim_age  perpetrator_age  economic_index  education_index  latitude  \
# 0             43                6       79.058164        30.831159  31.53230
# 1             25               87       29.381859        27.852306  32.18836
# 2             30               67       27.427779        98.695809  31.54848
# 3             90               59       91.489361        40.232219  31.38761
# 4             67               63       70.626686        14.110106  31.69213
# ...          ...              ...             ...              ...       ...
# 2995          53               50       19.790035        52.162548  31.48390
# 2996          16               90       88.873578        60.388386  31.65117
# 2997          96               76       77.509216         6.673806  31.02967
# 2998           9               53       86.543938        13.212119  32.16906
# 2999          63               81       89.101457        43.735559  31.42243
#
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from scipy.stats import randint, uniform
import joblib


# Define features and targets
X = traindf.drop(columns=['crime_type', 'location'])
y_crime = traindf['crime_type']
y_location = traindf['location']

# Split the data
X_train, X_test, y_train_crime, y_test_crime = train_test_split(X, y_crime, test_size=0.2, random_state=42)
_, _, y_train_location, y_test_location = train_test_split(X, y_location, test_size=0.2, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Set up RandomForestClassifier and parameters
RFC = RandomForestClassifier()
params = {
    "max_features": uniform(0.1, 0.9),
    "n_estimators": randint(100, 1000),
    "max_depth": randint(10, 50),
    "min_samples_split": randint(2, 20)
}

# RandomizedSearchCV for crime type
rnd_search_crime = RandomizedSearchCV(RFC, params, n_iter=30, cv=3, n_jobs=-1, random_state=42)
rnd_search_crime.fit(X_train_scaled, y_train_crime)
joblib.dump(rnd_search_crime, 'trained_random_forest_model_crime_type.pkl')

# Evaluate on training set
pred_train_crime = rnd_search_crime.predict(X_train_scaled)
train_accuracy_crime = accuracy_score(y_train_crime, pred_train_crime)
print('Train set accuracy for crime type:', train_accuracy_crime)

# Evaluate on test set
pred_test_crime = rnd_search_crime.predict(X_test_scaled)
test_accuracy_crime = accuracy_score(y_test_crime, pred_test_crime)
print('Test set accuracy for crime type:', test_accuracy_crime)
print(classification_report(y_test_crime, pred_test_crime))
print(confusion_matrix(y_test_crime, pred_test_crime))

# RandomizedSearchCV for location
rnd_search_location = RandomizedSearchCV(RFC, params, n_iter=30, cv=3, n_jobs=-1, random_state=42)
rnd_search_location.fit(X_train_scaled, y_train_location)
joblib.dump(rnd_search_location, 'trained_random_forest_model_location.pkl')

# Evaluate on training set
pred_train_location = rnd_search_location.predict(X_train_scaled)
train_accuracy_location = accuracy_score(y_train_location, pred_train_location)
print('Train set accuracy for location:', train_accuracy_location)

# Evaluate on test set
pred_test_location = rnd_search_location.predict(X_test_scaled)
test_accuracy_location = accuracy_score(y_test_location, pred_test_location)
print('Test set accuracy for location:', test_accuracy_location)
print(classification_report(y_test_location, pred_test_location))
print(confusion_matrix(y_test_location, pred_test_location))
# Out:
# Train set accuracy for crime type: 1.0
# Test set accuracy for crime type: 0.47333333333333333
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.53       323
#            1       0.42      0.39      0.41       277
#
#     accuracy                           0.47       600
#    macro avg       0.47      0.47      0.47       600
# weighted avg       0.47      0.47      0.47       600
#
# [[176 147]
#  [169 108]]
# c:\Users\Shamsullah\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# c:\Users\Shamsullah\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 44 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
# ...

# %% [markdown]
# Project after commint

# %%
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import pandas as pd
import joblib
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform
from scipy.stats import randint
from sklearn.metrics import mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor, StackingRegressor
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.decomposition import TruncatedSVD
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from scipy.sparse import hstack
from scipy import sparse
import pandas as pd
import numpy as np
import seaborn as sns

from copy import deepcopy

np.random.seed(42)

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %% [markdown]
# Loading Data

# %%
traindf = pd.read_csv('data.csv')
traindf.head(10)
# Out:
#                             date  hour_of_day   location victim_gender  \
# 0  2020-07-17 00:00:00.000000000            1  Arghistan        Female
# 1  2023-07-22 00:00:00.000000000            9   Kharkrez        Female
# 2  2022-07-20 00:00:00.000000000           17   Kharkrez        Female
# 3  2022-02-17 00:00:00.000000000           23      Zhari        Female
# 4  2023-08-31 00:00:00.000000000           15   Panjwayi        Female
# 5  2021-10-01 00:00:00.000000000           13      Maruf        Female
# 6  2022-01-08 00:00:00.000000000            2   Panjwayi          Male
# 7  2023-07-21 00:00:00.000000000           10       Reag          Male
# 8  2022-04-29 00:00:00.000000000            1       Nesh          Male
# 9  2023-11-02 00:00:00.000000000            5     Center        Female
#
#    victim_age perpetrator_gender  perpetrator_age weapon  injury weather  ...  \
# 0          64             Female               27  Knife  Severe   Clear  ...
# ...

# %%
traindf.describe()
# Out:
#        hour_of_day   victim_age  perpetrator_age  temperature  economic_index  \
# count  3036.000000  3036.000000      3036.000000  3036.000000     3036.000000
# mean     12.321476    50.640646        55.180830    14.997406       50.171170
# std       6.925688    28.869227        26.123681    14.462648       28.596749
# min       1.000000     1.000000        10.000000    -9.945373        0.034332
# 25%       6.000000    26.000000        33.000000     2.042438       26.133215
# 50%      12.000000    51.000000        55.000000    15.196518       49.266581
# 75%      18.000000    76.000000        78.000000    27.584696       74.665755
# max      24.000000   100.000000       100.000000    39.990634       99.981729
#
#        education_index
# count      3036.000000
# mean         48.823425
# std          29.246267
# min           0.003800
# 25%          23.708622
# 50%          47.669664
# 75%          75.043414
# max          99.957416

# %% [markdown]
# Descriptive Statistics

# %%
# Assuming 'traindf' is your dataframe
crime_counts = traindf['crime_type'].value_counts()
location_counts = traindf['location'].value_counts()

print("Crime Type Counts:")
print(crime_counts)

print("\nLocation Counts:")
print(location_counts)
# Out:
# Crime Type Counts:
# crime_type
# Kill     1518
# Theft    1518
# Name: count, dtype: int64
#
# Location Counts:
# location
# Zhari            275
# Maywand          270
# Shah Wali Kot    260
# Center           259
# Spin Boldak      258
# Kharkrez         250
# Daman            250
# Maruf            242
# Panjwayi         239
# Nesh             238
# Arghistan        236
# Reag             223
# Name: count, dtype: int64

# %% [markdown]
# Cross-Tabulation

# %%
# Replace 'Preferred Career Path' and 'Accommodation Mode' with relevant columns from your dataset
cross_table = pd.crosstab(traindf['crime_type'], traindf['location'])

print("Cross-tabulation of Crime Type and Location:")
print(cross_table)
# Out:
# Cross-tabulation of Crime Type and Location:
# location    Arghistan  Center  Daman  Kharkrez  Maruf  Maywand  Nesh  \
# crime_type
# Kill              121     128    128       115    112      136   140
# Theft             115     131    122       135    130      134    98
#
# location    Panjwayi  Reag  Shah Wali Kot  Spin Boldak  Zhari
# crime_type
# Kill             121   123            129          131    134
# Theft            118   100            131          127    141

# %%
# Example: Crosstab and plot for Crime Type and Location
pd.crosstab(traindf['crime_type'], traindf['location']).plot(kind='bar', figsize=(12, 8))

plt.title("Crime Type Frequency for Different Locations")
plt.xlabel("Crime Type")
plt.ylabel("Frequency")
plt.legend(title='Location', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
# Plot histogram for victim age
plt.figure(figsize=(10, 6))
traindf['victim_age'].plot.hist(bins=20, edgecolor='black')
plt.title('Histogram of Victim Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Plot histogram for a relevant attribute (example: victim_age)
traindf['victim_age'].plot.hist(bins=20, edgecolor='black')
plt.title('Distribution of Victim Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import uniform, randint

# Load your data
# Assuming 'traindf' is your dataframe

# Define the numeric and categorical features based on your dataset
numeric_features = ['victim_age', 'perpetrator_age', 'economic_index', 'education_index']
categorical_features = ['location', 'victim_gender', 'perpetrator_gender', 'weapon', 'weather_condition']

# %%
# Custom Transformer for Data Preprocessing
class DataPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self, numeric_features, categorical_features):
        self.numeric_features = numeric_features
        self.categorical_features = categorical_features
        
        self.numeric_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ])
        
        self.categorical_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ])
        
        self.preprocessor = ColumnTransformer([
            ('numeric', self.numeric_pipeline, self.numeric_features),
            ('categorical', self.categorical_pipeline, self.categorical_features)
        ])
        
    def fit(self, X, y=None):
        self.preprocessor.fit(X)
        return self
    
    def transform(self, X):
        return self.preprocessor.transform(X)

# Instantiate the DataPreprocessor
data_preprocessor = DataPreprocessor(numeric_features, categorical_features)

# Fit and transform your data
X_processed = data_preprocessor.fit_transform(traindf)

print("Preprocessing complete.")
# Out:
# Preprocessing complete.

# %%
# Define your features (X) and target (y)
X = traindf.drop(['crime_type', 'location'], axis=1)  # Adjust columns as per your actual column names
y_crime_type = traindf['crime_type']
y_location = traindf['location']

# Check for any null values in your target variables
print("Null values in Crime Type:")
print(y_crime_type.isnull().any())

print("\nNull values in Location:")
print(y_location.isnull().any())
# Out:
# Null values in Crime Type:
# False
#
# Null values in Location:
# True

# %%
traindf.columns
# Out:
# Index(['date', 'hour_of_day', 'location', 'victim_gender', 'victim_age',
#        'perpetrator_gender', 'perpetrator_age', 'weapon', 'injury', 'weather',
#        'temperature', 'previous_activity', 'economical_situation',
#        'education_level', 'crime_type', 'time_of_day', 'day_of_week', 'month',
#        'season', 'victim_age_group', 'perpetrator_age_group',
#        'weather_condition', 'economic_index', 'education_index'],
#       dtype='object')

# %% [markdown]
# Train-Test Split

# %%
# Define features and target variables
features = traindf[['date', 'hour_of_day', 'location',
                    'victim_gender', 'victim_age', 'perpetrator_gender', 'perpetrator_age',
                    'weapon', 'time_of_day', 'day_of_week', 'month', 'season',
                    'victim_age_group', 'perpetrator_age_group', 'weather_condition',
                    'economic_index', 'education_index']]

target = traindf[['crime_type', 'location']]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Output the results
print("X_train:")
print(x_train.head())

print("\nX_test:")
print(x_test.head())

print("\nY_train:")
print(y_train.head())

print("\nY_test:")
print(y_test.head())
# Out:
# X_train:
#                                date  hour_of_day     location victim_gender  \
# 227   2023-05-21 00:00:00.000000000            7        Daman          Male
# 365   2021-06-08 00:00:00.000000000           10      Maywand          Male
# 2924  2022-07-27 00:00:00.000000000           11  Spin Boldak          Male
# 2501  2023-12-24 00:00:00.000000000           22      Maywand        Female
# 2001  2023-09-20 00:00:00.000000000           23  Spin Boldak        Female
#
#       victim_age perpetrator_gender  perpetrator_age weapon time_of_day  \
# 227           23             Female               64  Other   Afternoon
# 365           47             Female               87  Knife       Night
# 2924          44             Female               20  Other   Afternoon
# 2501          17             Female               32    NaN       Night
# 2001          17               Male               85    Gun     Morning
#
# ...

# %% [markdown]
# Column Transformer Setup

# %%
# Identify numerical and categorical columns
numerical_cols = x_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = x_train.select_dtypes(include=['category', 'object']).columns

print("The numerical columns:", numerical_cols)
print("The categorical columns:", categorical_cols)

# Create a column transformer for preprocessing
col_tsf = ColumnTransformer(
    transformers=[
        ('num', Pipeline([('imputer', SimpleImputer(strategy='median')), ('scaler', StandardScaler())]), numerical_cols),
        ('cat', Pipeline([('imputer', SimpleImputer(strategy='most_frequent')), ('onehot', OneHotEncoder(handle_unknown='ignore'))]), categorical_cols)
    ],
    remainder='passthrough'
)

# Fit and transform the training data
x_preprocessed_train = col_tsf.fit_transform(x_train)

# Transform the test data
x_preprocessed_test = col_tsf.transform(x_test)

# Save the column transformer
joblib.dump(col_tsf, 'column_transformer.pkl')

print("Preprocessing complete.")
# Out:
# The numerical columns: Index(['hour_of_day', 'victim_age', 'perpetrator_age', 'economic_index',
#        'education_index'],
#       dtype='object')
# The categorical columns: Index(['date', 'location', 'victim_gender', 'perpetrator_gender', 'weapon',
#        'time_of_day', 'day_of_week', 'month', 'season', 'victim_age_group',
#        'perpetrator_age_group', 'weather_condition'],
#       dtype='object')
# Preprocessing complete.

# %%
# Define the RandomForestClassifier
RFC = RandomForestClassifier()

# Define the parameter grid with optimized values
prams = {
    "max_features": uniform(0.1, 0.5),
    "n_estimators": randint(50, 200),
    "max_depth": randint(10, 30),
    "min_samples_split": randint(2, 10)
}

# Train and evaluate separate classifiers for crime type and location
def train_and_evaluate(x_train, y_train, prams, model_name):
    rnd_search = RandomizedSearchCV(RFC, prams, n_iter=30, cv=3, n_jobs=-1, random_state=42)
    rndx = rnd_search.fit(x_train, y_train)
    
    # Save the trained model
    joblib.dump(rndx, f'trained_random_forest_model_for_{model_name}.pkl')

    return rndx

# Separate the target variables into crime type and location
y_train_type = y_train['crime_type']
y_train_location = y_train['location']

# Train and save models
rndx_type = train_and_evaluate(x_preprocessed_train, y_train_type, prams, "crime_type")
rndx_location = train_and_evaluate(x_preprocessed_train, y_train_location, prams, "location")

print("Hyperparameter tuning complete.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 28
#      26 # Train and save models
#      27 rndx_type = train_and_evaluate(x_preprocessed_train, y_train_type, prams, "crime_type")
# ---> 28 rndx_location = train_and_evaluate(x_preprocessed_train, y_train_location, prams, "location")
#      30 print("Hyperparameter tuning complete.")
#
# Cell In[38], line 15, in train_and_evaluate(x_train, y_train, prams, model_name)
#      13 def train_and_evaluate(x_train, y_train, prams, model_name):
#      14     rnd_search = RandomizedSearchCV(RFC, prams, n_iter=30, cv=3, n_jobs=-1, random_state=42)
# ---> 15     rndx = rnd_search.fit(x_train, y_train)
#      17     # Save the trained model
#      18     joblib.dump(rndx, f'trained_random_forest_model_for_{model_name}.pkl')
#
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score

# Load the trained models
rndx_type = joblib.load('trained_random_forest_model_for_crime_type.pkl')
rndx_location = joblib.load('trained_random_forest_model_for_location.pkl')

# Predictions for crime type
y_pred_type = rndx_type.predict(x_preprocessed_test)
print("Classification Report for Crime Type:")
print(classification_report(y_test['crime_type'], y_pred_type))

# Predictions for location
y_pred_location = rndx_location.predict(x_preprocessed_test)
print("Classification Report for Location:")
print(classification_report(y_test['location'], y_pred_location))

# Accuracy scores
print("Accuracy for Crime Type:", accuracy_score(y_test['crime_type'], y_pred_type))
print("Accuracy for Location:", accuracy_score(y_test['location'], y_pred_location))
# Out:
# Classification Report for Crime Type:
#               precision    recall  f1-score   support
#
#         Kill       0.53      0.58      0.56       318
#        Theft       0.48      0.43      0.45       282
#
#     accuracy                           0.51       600
#    macro avg       0.51      0.51      0.50       600
# weighted avg       0.51      0.51      0.51       600
#
# Classification Report for Location:
#                precision    recall  f1-score   support
#
#     Arghistan       1.00      1.00      1.00        48
#        Center       1.00      1.00      1.00        49
#         Daman       1.00      1.00      1.00        45
#      Kharkrez       1.00      1.00      1.00        42
#         Maruf       1.00      1.00      1.00        56
#       Maywand       1.00      1.00      1.00        47
#          Nesh       1.00      1.00      1.00        46
#      Panjwayi       1.00      1.00      1.00        52
#          Reag       1.00      1.00      1.00        52
# ...

# %% [markdown]
# # Model Training And Evaluation

# %%
# Finalize the code and save necessary artifacts
joblib.dump(rndx_type, 'final_random_forest_model_for_crime_type.pkl')
joblib.dump(rndx_location, 'final_random_forest_model_for_location.pkl')

print("Model training and evaluation complete.")
# Out:
# Model training and evaluation complete.

# %%
combined_data
# Out:
#       victim_age  perpetrator_age  temperature  economic_index  \
# 0             49               28     9.822727       90.353439
# 1             20              100     6.275022       76.257845
# 2             95               15     8.572979       18.348836
# 3             63               15     3.201645       70.453815
# 4             11              100    19.138534       92.237705
# ...          ...              ...          ...             ...
# 2995          56                5    16.846615       64.021114
# 2996           3               36    32.714271       70.217494
# 2997          39               27     4.748465       99.853398
# 2998          18               90    25.036564       18.467951
# 2999          21               67     4.937580       56.074053
#
#       education_index  location_encoded  victim_gender_encoded  \
# 0           51.445324                 8                      1
# 1           10.994998                 9                      0
# ...

# %%
# Finalize the code and save necessary artifacts
joblib.dump(rndx_type, 'final_random_forest_model_for_crime_type.pkl')
joblib.dump(rndx_location, 'final_random_forest_model_for_location.pkl')

print("Model training and evaluation complete.")

# Load the final models
final_model_crime_type = joblib.load('final_random_forest_model_for_crime_type.pkl')
final_model_location = joblib.load('final_random_forest_model_for_location.pkl')

# Function to make predictions
def predict_crime_and_location(model_crime_type, model_location, data):
    # Preprocess the input data
    data_preprocessed = col_tsf.transform(data)
    
    # Predict crime type
    crime_type_pred = model_crime_type.predict(data_preprocessed)
    crime_type_prob = model_crime_type.predict_proba(data_preprocessed)
    
    # Predict location
    location_pred = model_location.predict(data_preprocessed)
    location_prob = model_location.predict_proba(data_preprocessed)
    
    return crime_type_pred, crime_type_prob, location_pred, location_prob

# Example input data for prediction (replace with actual input data)
# Assuming 'input_data' is a DataFrame with the same structure as your features
input_data = x_test.copy()  # For demonstration, using the test data

# Make predictions
crime_type_pred, crime_type_prob, location_pred, location_prob = predict_crime_and_location(final_model_crime_type, final_model_location, input_data)

# # Output the predictions
# print("Predicted Crime Types:")
# print(crime_type_pred)

# print("\nProbabilities for Crime Types:")
# print(crime_type_prob)

# print("\nPredicted Locations:")
# print(location_pred)

# print("\nProbabilities for Locations:")
# print(location_prob)

# Combine predictions and probabilities into a DataFrame
predictions_with_probabilities = pd.DataFrame({
    'Crime_Type_Prediction': crime_type_pred,
    'Location_Prediction': location_pred,
    'Crime_Type_Probability': [max(prob) for prob in crime_type_prob],
    'Location_Probability': [max(prob) for prob in location_prob]
})

# Group by Crime_Type_Prediction and select the location with the highest probability
best_locations_for_crimes = predictions_with_probabilities.loc[
    predictions_with_probabilities.groupby('Crime_Type_Prediction')['Location_Probability'].idxmax()
]

print("Best Locations for Each Crime Type with Highest Probability:")
print(best_locations_for_crimes)
# Out:
# Model training and evaluation complete.
# Best Locations for Each Crime Type with Highest Probability:
#   Crime_Type_Prediction Location_Prediction  Crime_Type_Probability  \
# 0                  Kill                Reag                0.695000
# 2                 Theft               Daman                0.505545
#
#    Location_Probability
# 0                   1.0
# 2                   1.0

# %%
# Summarize predictions with probabilities
predictions_summary = pd.DataFrame({
    'Crime_Type_Prediction': crime_type_pred,
    'Crime_Type_Probability': [max(prob) for prob in crime_type_prob],
    'Location_Prediction': location_pred,
    'Location_Probability': [max(prob) for prob in location_prob]
})

print("\nSummary of Predictions with Probabilities:")
print(predictions_summary)
# Out:
# Summary of Predictions with Probabilities:
#     Crime_Type_Prediction  Crime_Type_Probability Location_Prediction  \
# 0                    Kill                0.695000                Reag
# 1                    Kill                0.688792               Daman
# 2                   Theft                0.505545               Daman
# 3                    Kill                0.528757                Reag
# 4                    Kill                0.553918            Panjwayi
# ..                    ...                     ...                 ...
# 595                 Theft                0.513757               Zhari
# 596                  Kill                0.556667               Zhari
# 597                  Kill                0.533958                Reag
# 598                  Kill                0.569167         Spin Boldak
# 599                 Theft                0.558515             Maywand
#
#      Location_Probability
# 0                 1.00000
# 1                 1.00000
# ...

# %%
# Combine predictions and probabilities into a DataFrame
predictions_with_probabilities = pd.DataFrame({
    'Crime_Type_Prediction': crime_type_pred,
    'Location_Prediction': location_pred,
    'Crime_Type_Probability': [max(prob) for prob in crime_type_prob],
    'Location_Probability': [max(prob) for prob in location_prob]
})

# Group by Crime_Type_Prediction and select the location with the highest probability
best_locations_for_crimes = predictions_with_probabilities.loc[
    predictions_with_probabilities.groupby('Crime_Type_Prediction')['Location_Probability'].idxmax()
]

print("Best Locations for Each Crime Type with Highest Probability:")
print(best_locations_for_crimes)
# Out:
# Best Locations for Each Crime Type with Highest Probability:
#   Crime_Type_Prediction Location_Prediction  Crime_Type_Probability  \
# 0                  Kill                Reag                0.695000
# 2                 Theft               Daman                0.505545
#
#    Location_Probability
# 0                   1.0
# 2                   1.0

# %% [markdown]
# #new work with model

# %%
import sys
assert sys.version_info >= (3, 5)

import sklearn
assert sklearn.__version__ >= "0.20"

import numpy as np
import pandas as pd
import joblib
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import uniform, randint
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)
# %matplotlib inline

# %%
traindf = pd.read_csv('data.csv')
print(traindf.head(10))

crime_counts = traindf['crime_type'].value_counts()
location_counts = traindf['location'].value_counts()

print("Crime Type Counts:")
print(crime_counts)

print("\nLocation Counts:")
print(location_counts)
# Out:
#                             date  hour_of_day   location victim_gender  \
# 0  2020-07-17 00:00:00.000000000            1  Arghistan        Female
# 1  2023-07-22 00:00:00.000000000            9   Kharkrez        Female
# 2  2022-07-20 00:00:00.000000000           17   Kharkrez        Female
# 3  2022-02-17 00:00:00.000000000           23      Zhari        Female
# 4  2023-08-31 00:00:00.000000000           15   Panjwayi        Female
# 5  2021-10-01 00:00:00.000000000           13      Maruf        Female
# 6  2022-01-08 00:00:00.000000000            2   Panjwayi          Male
# 7  2023-07-21 00:00:00.000000000           10       Reag          Male
# 8  2022-04-29 00:00:00.000000000            1       Nesh          Male
# 9  2023-11-02 00:00:00.000000000            5     Center        Female
#
#    victim_age perpetrator_gender  perpetrator_age weapon  injury weather  ...  \
# 0          64             Female               27  Knife  Severe   Clear  ...
# ...

# %%
cross_table = pd.crosstab(traindf['crime_type'], traindf['location'])
print("Cross-tabulation of Crime Type and Location:")
print(cross_table)

pd.crosstab(traindf['crime_type'], traindf['location']).plot(kind='bar', figsize=(12, 8))
plt.title("Crime Type Frequency for Different Locations")
plt.xlabel("Crime Type")
plt.ylabel("Frequency")
plt.legend(title='Location', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

plt.figure(figsize=(10, 6))
traindf['victim_age'].plot.hist(bins=20, edgecolor='black')
plt.title('Histogram of Victim Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Cross-tabulation of Crime Type and Location:
# location    Arghistan  Center  Daman  Kharkrez  Maruf  Maywand  Nesh  \
# crime_type
# Kill              121     128    128       115    112      136   140
# Theft             115     131    122       135    130      134    98
#
# location    Panjwayi  Reag  Shah Wali Kot  Spin Boldak  Zhari
# crime_type
# Kill             121   123            129          131    134
# Theft            118   100            131          127    141

# %%
numeric_features = ['victim_age', 'perpetrator_age', 'economic_index', 'education_index']
categorical_features = ['location', 'victim_gender', 'perpetrator_gender', 'weapon', 'weather_condition']

class DataPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self, numeric_features, categorical_features):
        self.numeric_features = numeric_features
        self.categorical_features = categorical_features
        
        self.numeric_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ])
        
        self.categorical_pipeline = Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ])
        
        self.preprocessor = ColumnTransformer([
            ('numeric', self.numeric_pipeline, self.numeric_features),
            ('categorical', self.categorical_pipeline, self.categorical_features)
        ])
        
    def fit(self, X, y=None):
        self.preprocessor.fit(X)
        return self
    
    def transform(self, X):
        return self.preprocessor.transform(X)

data_preprocessor = DataPreprocessor(numeric_features, categorical_features)
X_processed = data_preprocessor.fit_transform(traindf)

# %%
X = traindf.drop(['crime_type', 'location'], axis=1)
y_crime_type = traindf['crime_type']
y_location = traindf['location']

print("Null values in Crime Type:")
print(y_crime_type.isnull().any())

print("\nNull values in Location:")
print(y_location.isnull().any())
# Out:
# Null values in Crime Type:
# False
#
# Null values in Location:
# True

# %%
features = traindf[['date', 'hour_of_day', 'location',
                    'victim_gender', 'victim_age', 'perpetrator_gender', 'perpetrator_age',
                    'weapon', 'time_of_day', 'day_of_week', 'month', 'season',
                    'victim_age_group', 'perpetrator_age_group', 'weather_condition',
                    'economic_index', 'education_index']]
target = traindf[['crime_type', 'location']]

x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

print("X_train:")
print(x_train.head())

print("\nX_test:")
print(x_test.head())

print("\nY_train:")
print(y_train.head())

print("\nY_test:")
print(y_test.head())
# Out:
# X_train:
#                                date  hour_of_day     location victim_gender  \
# 227   2023-05-21 00:00:00.000000000            7        Daman          Male
# 365   2021-06-08 00:00:00.000000000           10      Maywand          Male
# 2924  2022-07-27 00:00:00.000000000           11  Spin Boldak          Male
# 2501  2023-12-24 00:00:00.000000000           22      Maywand        Female
# 2001  2023-09-20 00:00:00.000000000           23  Spin Boldak        Female
#
#       victim_age perpetrator_gender  perpetrator_age weapon time_of_day  \
# 227           23             Female               64  Other   Afternoon
# 365           47             Female               87  Knife       Night
# 2924          44             Female               20  Other   Afternoon
# 2501          17             Female               32    NaN       Night
# 2001          17               Male               85    Gun     Morning
#
# ...

# %%
numerical_cols = x_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = x_train.select_dtypes(include=['category', 'object', 'bool']).columns

print("The numerical columns:", numerical_cols)
print("The categorical columns:", categorical_cols)

col_tsf = ColumnTransformer([
    ('num', Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]), numerical_cols),
    ('cat', Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ]), categorical_cols)
], remainder='passthrough')

x_preprocessed_train = col_tsf.fit_transform(x_train)
x_preprocessed_test = col_tsf.transform(x_test)

joblib.dump(col_tsf, 'column_transformer.pkl')
print("Preprocessing complete.")
# Out:
# The numerical columns: Index(['hour_of_day', 'victim_age', 'perpetrator_age', 'economic_index',
#        'education_index'],
#       dtype='object')
# The categorical columns: Index(['date', 'location', 'victim_gender', 'perpetrator_gender', 'weapon',
#        'time_of_day', 'day_of_week', 'month', 'season', 'victim_age_group',
#        'perpetrator_age_group', 'weather_condition'],
#       dtype='object')
# Preprocessing complete.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import joblib
from scipy.stats import randint, uniform

# فرض کړئ چې داده مخکې لوډ شوې ده
df = pd.read_csv('data.csv')

# کالمونه تعریفول
numeric_features = ['hour_of_day', 'victim_age', 'perpetrator_age', 'temperature', 'economic_index', 'education_index']
categorical_features = ['location', 'victim_gender', 'perpetrator_gender', 'weapon', 'injury', 'weather', 'previous_activity', 'economical_situation', 'education_level', 'time_of_day', 'day_of_week', 'month', 'season', 'victim_age_group', 'perpetrator_age_group', 'weather_condition']

# د پايپ لاين لپاره ترانسفارمرونه تعریفول
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# ستاسو داده چمتو کول (فرض کړئ df داده په مخکینیو سټیپونو کې لوډ شوی دی)
try:
    X = df.drop(['crime_type', 'date'], axis=1)
    y_type = df['crime_type']
    y_location = df['location']
except NameError:
    print("df is not defined. Make sure the dataframe is loaded properly.")
    # داده دلته بیا لوډ کړئ که df نه وي لوډ شوی:
    df = pd.read_csv('data.csv')
    X = df.drop(['crime_type', 'date'], axis=1)
    y_type = df['crime_type']
    y_location = df['location']

# د شمیري او کتګوری کلومونو ډاډ ترلاسه کول
X[numeric_features] = X[numeric_features].apply(pd.to_numeric, errors='coerce')
X[categorical_features] = X[categorical_features].astype(str)

# د ټرین او ټسټ داده ویشل
X_train, X_test, y_train_type, y_test_type = train_test_split(X, y_type, test_size=0.2, random_state=42)
_, _, y_train_location, y_test_location = train_test_split(X, y_location, test_size=0.2, random_state=42)

# هایپر پارامترونه
prams = {
    "classifier__max_features": uniform(0.1, 0.5),
    "classifier__n_estimators": randint(50, 200),
    "classifier__max_depth": randint(10, 30),
    "classifier__min_samples_split": randint(2, 10)
}

def train_and_evaluate(x_train, y_train, prams, model_name):
    clf = Pipeline(steps=[('preprocessor', preprocessor),
                          ('classifier', RandomForestClassifier())])
    
    rnd_search = RandomizedSearchCV(clf, param_distributions=prams, n_iter=30, cv=3, n_jobs=-1, random_state=42)
    rndx = rnd_search.fit(x_train, y_train)
    joblib.dump(rndx, f'trained_random_forest_model_for_{model_name}.pkl')
    return rndx

rndx_type = train_and_evaluate(X_train, y_train_type, prams, "crime_type")
rndx_location = train_and_evaluate(X_train, y_train_location, prams, "location")

print("Hyperparameter tuning complete.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 75
#      72     return rndx
#      74 rndx_type = train_and_evaluate(X_train, y_train_type, prams, "crime_type")
# ---> 75 rndx_location = train_and_evaluate(X_train, y_train_location, prams, "location")
#      77 print("Hyperparameter tuning complete.")
#
# Cell In[63], line 70, in train_and_evaluate(x_train, y_train, prams, model_name)
#      66 clf = Pipeline(steps=[('preprocessor', preprocessor),
#      67                       ('classifier', RandomForestClassifier())])
#      69 rnd_search = RandomizedSearchCV(clf, param_distributions=prams, n_iter=30, cv=3, n_jobs=-1, random_state=42)
# ---> 70 rndx = rnd_search.fit(x_train, y_train)
#      71 joblib.dump(rndx, f'trained_random_forest_model_for_{model_name}.pkl')
#      72 return rndx
#
# ...

# %%
joblib.dump(rndx_type, 'final_random_forest_model_for_crime_type.pkl')
joblib.dump(rndx_location, 'final_random_forest_model_for_location.pkl')

print("Model training and evaluation complete.")

final_model_crime_type = joblib.load('final_random_forest_model_for_crime_type.pkl')
final_model_location = joblib.load('final_random_forest_model_for_location.pkl')

def predict_crime_and_location(model_crime_type, model_location, data):
    data_preprocessed = col_tsf.transform(data)
    
    crime_type_pred = model_crime_type.predict(data_preprocessed)
    crime_type_prob = model_crime_type.predict_proba(data_preprocessed)
    
    location_pred = model_location.predict(data_preprocessed)
    location_prob = model_location.predict_proba(data_preprocessed)
    
    return crime_type_pred, crime_type_prob, location_pred, location_prob

input_data = x_test.copy()

crime_type_pred, crime_type_prob, location_pred, location_prob = predict_crime_and_location(final_model_crime_type, final_model_location, input_data)

predictions_with_probabilities = pd.DataFrame({
    'Crime_Type_Prediction': crime_type_pred,
    'Location_Prediction': location_pred,
    'Crime_Type_Probability': [max(prob) for prob in crime_type_prob],
    'Location_Probability': [max(prob) for prob in location_prob]
})

best_locations_for_crimes = predictions_with_probabilities.loc[
    predictions_with_probabilities.groupby('Crime_Type_Prediction')['Location_Probability'].idxmax()
]

print("Best Locations for Each Crime Type with Highest Probability:")
print(best_locations_for_crimes)
# Out:
# Model training and evaluation complete.
# Best Locations for Each Crime Type with Highest Probability:
#   Crime_Type_Prediction Location_Prediction  Crime_Type_Probability  \
# 0                  Kill                Reag                0.588394
# 6                 Theft              Center                0.531766
#
#    Location_Probability
# 0                   1.0
# 6                   1.0
